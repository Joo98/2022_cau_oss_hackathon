# %% [markdown]
# <a href="https://colab.research.google.com/github/Joo98/2022_cau_oss_hackathon/blob/main/hackathon_team06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **0. 해커톤 진행 주의사항**
#
# **1)  개발 관련 주의사항**
# *   [1. 초기 환경 설정]은 절대 수정하지 말 것
# *   모든 구현은 [2. 데이터 전처리] 및 [3.모델 생성]에서만 진행
# *   [4. 모델 저장]에서 team_name 변수 변경 (예.`team_name = 'team01'`)
#  *    트레이닝 중간에 checkpoint를 활용하여 모델을 저장한 경우에도 파일 이름 양식 통일 필수
# *   Colab 사용중 실수로 데이터 손실이 발생할 수도 있으니 중간 결과값을 github에 업로드
#  *    "런타임 -> 런타임 연결 해제 및 삭제"은 절대 누르지 말 것 (저장한 모델 데이터가 모두 삭제됨)
#  *    "런타임 -> 런타임 다시시작"은 클라우드 스토리지에 저장된 모델은 유지됨
# *   효율적인 구현 및 테스팅을 위해 GPU 가속 기능 활성화
#  *    "런타임 -> 런타임 유형변경 -> 하드웨어 가속기 -> GPU 설정"
# *   주석을 최대한 자세히 작성
# *   Keras API 관련하여 [Keras Documentation](https://keras.io/) 참조
#
# **2) 제출 관련 주의사항**
# *  제출물
#  *  소스코드 (hackathon_teamXX.ipynb)
#  *  컴파일된 모델 파일 (model_entire_teamXX.h5)
#  *  모델 발표 자료
# * 제출 기한: **오후 6시 (단, 발표자료는 12시)**
# * 제출 방법: [GitHub README](https://github.com/cauosshackathonta/2022_cau_oss_hackathon/) 참조
#
#
# **3) 평가 관련 주의사항**
# *  모델 성능 = 테스트 데이터 셋 분류 정확도
#  *  model.evaluate(x_test, y_test)
# *  제출된 모델들의 테스트 데이터 셋 분류 정확도를 기준으로 수상작 결정
# *  수상 후보들에 대해서는 소스코드를 기반으로 모델 재검증
#
# **4) 수상 실격 사유**
# *  유사한 소스코드가 적발될 경우
# *  Pre-trained 모델을 사용한 경우 (transfer learning 포함)
# *  소스코드와 제출된 모델이 상이한 경우
# *  개발 관련 주의사항을 지키지 않은 경우
#  *  예: [초기 환경 설정]을 수정한 경우
# *  데이터 셋을 변조한 경우
#  *  예. 테스트 데이터 셋을 트레이닝 데이터 셋에 포함하여 모델 생성
# *  주석이 소스코드와 맞지 않거나 미비할 경우

# %% [markdown]
# # **1. 초기 환경 설정**

# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

# tensorflow와 tf.keras 및 관련 라이브러리 임포트
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np

from tensorflow import keras
from keras.utils import np_utils
from keras import datasets, layers, models

# 데이터셋 로드 (MNIST, fashion-MNIST, Kujushiji-MNIST, MNIST_corrupted (test only))
train_ds, test_ds = tfds.load('mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)

train_ds2, test_ds2 = tfds.load('fashion_mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds2['label'] += 10;
test_ds2['label'] += 10;

train_ds3, test_ds3 = tfds.load('kmnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds3['label'] += 20;
test_ds3['label'] += 20;

test_ds4 = tfds.load('mnist_corrupted/zigzag', split='test', shuffle_files=False, batch_size=-1)

# 데이터셋 병합 (training: 180,000개, test: 40,000개)
x_train = np.append(np.append(train_ds['image'], train_ds2['image'], 0), train_ds3['image'], 0);
y_train = np.append(np.append(train_ds['label'], train_ds2['label'], 0), train_ds3['label'], 0);

x_test = np.append(np.append(np.append(test_ds['image'], test_ds2['image'], 0), test_ds3['image'], 0), test_ds4['image'], 0);
y_test = np.append(np.append(np.append(test_ds['label'], test_ds2['label'], 0), test_ds3['label'], 0), test_ds4['label'], 0);

# 분류를 위해 클래스 벡터를 바이너리 매트릭스로 변환
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# 총 클래스 개수: 30, 입력 데이터 구조: (28, 28, 1)
num_classes = y_train.shape[1]
input_shape = x_train.shape[1:]
print(num_classes, input_shape)
# Out:
# Downloading and preparing dataset 11.06 MiB (download: 11.06 MiB, generated: 21.00 MiB, total: 32.06 MiB) to ~/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...:   0%|          | 0/4 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to ~/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 29.45 MiB (download: 29.45 MiB, generated: 36.42 MiB, total: 65.87 MiB) to ~/tensorflow_datasets/fashion_mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incomplete9J80FB/fashion_mnist-train.tfrecord*...:   0%|  …
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incomplete9J80FB/fashion_mnist-test.tfrecord*...:   0%|   …
# Dataset fashion_mnist downloaded and prepared to ~/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 20.26 MiB (download: 20.26 MiB, generated: 31.76 MiB, total: 52.02 MiB) to ~/tensorflow_datasets/kmnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incomplete7Y58DH/kmnist-train.tfrecord*...:   0%|          | 0/60…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incomplete7Y58DH/kmnist-test.tfrecord*...:   0%|          | 0/100…
# Dataset kmnist downloaded and prepared to ~/tensorflow_datasets/kmnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 235.23 MiB (download: 235.23 MiB, generated: Unknown size, total: 235.23 MiB) to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incompleteY8BDWU/mnist_corrupted-train.tfrecord*.…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incompleteY8BDWU/mnist_corrupted-test.tfrecord*..…
# Dataset mnist_corrupted downloaded and prepared to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0. Subsequent calls will reuse this data.
# 30 (28, 28, 1)

# %% [markdown]
# # **2. 데이터 전처리**

# %%
# 데이터 전처리 (예: normalization)
# 원본 데이터와 전처리 후 데이터를 구분하기 위해, 변수명 x_train_after, x_test_after를 변경하지 말 것
x_train_after = x_train / 255
x_test_after = x_test / 255

x_train_after = tf.image.resize(x_train_after, (32,32))
x_test_after = tf.image.resize(x_test_after, (32,32))

# %% [markdown]
# # **3. 모델 생성**

# %%
image_size = x_train_after.shape[1]
num_classes = y_train.shape[1]

batch_size = 128
learning_rate = 0.001
epochs = 50
last_dim = 200

base_model = keras.applications.ResNet50V2(include_top=False, input_shape=(image_size, image_size, 1), weights=None)

model = keras.models.Sequential([
        base_model,
        keras.layers.GlobalAveragePooling2D(),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(last_dim, activation='relu'),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(num_classes, activation='softmax'),
])

# 모델 컴파일
# optimizer: 모델을 업데이트 하는 방식
# loss: 모델의 정확도를 판단하는 방식
# metrics: 트레이닝 및 테스팅 성능 모니터링을 위한 평가지표
model.compile(loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1), optimizer=keras.optimizers.Adam(learning_rate=learning_rate), metrics=['accuracy'])


# 체크포인트 생성
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/checkpoint_entire_best.h5', monitor='val_accuracy', verbose=1, save_weight_only=False, save_best_only=True, mode='auto')

# 모델 트레이닝
# batch_size: 전체 데이터셋 중 몇개씩 학습시킬 것인지
# epoch: 학습에 전체 데이터셋이 총 몇번 이용될 것인지
# shuffle: 학습전에 트레이닝 데이터셋을 랜덤하게 섞을 것인지
# validation_data: 중간 성능 검증에 사용할 data set (x_test1_after, x_test2_after, 혹은 둘을 merge해서 사용)
model.fit(x_train_after, y_train, 
          batch_size = batch_size, 
          epochs = epochs, 
          shuffle=True, 
          callbacks=[cp_callback], 
          validation_data=(x_test_after, y_test))

model.summary()
# Out:
# Epoch 1/50
# 1407/1407 [==============================] - ETA: 0s - loss: 1.0039 - accuracy: 0.8853
# Epoch 1: val_accuracy improved from -inf to 0.83255, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 113s 68ms/step - loss: 1.0039 - accuracy: 0.8853 - val_loss: 1.1472 - val_accuracy: 0.8325
# Epoch 2/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.8310 - accuracy: 0.9411
# Epoch 2: val_accuracy improved from 0.83255 to 0.84055, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 93s 66ms/step - loss: 0.8310 - accuracy: 0.9411 - val_loss: 1.1484 - val_accuracy: 0.8406
# Epoch 3/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.8042 - accuracy: 0.9485
# Epoch 3: val_accuracy improved from 0.84055 to 0.87075, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 92s 65ms/step - loss: 0.8042 - accuracy: 0.9485 - val_loss: 1.0209 - val_accuracy: 0.8708
# Epoch 4/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7886 - accuracy: 0.9533
# Epoch 4: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.7887 - accuracy: 0.9533 - val_loss: 1.1502 - val_accuracy: 0.8324
# Epoch 5/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7774 - accuracy: 0.9570
# Epoch 5: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.7774 - accuracy: 0.9570 - val_loss: 1.2153 - val_accuracy: 0.8297
# Epoch 6/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7688 - accuracy: 0.9600
# Epoch 6: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.7688 - accuracy: 0.9600 - val_loss: 1.2303 - val_accuracy: 0.8232
# Epoch 7/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7580 - accuracy: 0.9633
# Epoch 7: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.7580 - accuracy: 0.9633 - val_loss: 1.1399 - val_accuracy: 0.8383
# Epoch 8/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7578 - accuracy: 0.9645
# Epoch 8: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.7578 - accuracy: 0.9645 - val_loss: 1.1742 - val_accuracy: 0.8359
# Epoch 9/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7518 - accuracy: 0.9658
# Epoch 9: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.7519 - accuracy: 0.9658 - val_loss: 1.6430 - val_accuracy: 0.7066
# Epoch 10/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7427 - accuracy: 0.9688
# Epoch 10: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.7427 - accuracy: 0.9688 - val_loss: 1.1238 - val_accuracy: 0.8449
# Epoch 11/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7291 - accuracy: 0.9732
# Epoch 11: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.7291 - accuracy: 0.9732 - val_loss: 1.1473 - val_accuracy: 0.8388
# Epoch 12/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7435 - accuracy: 0.9686
# Epoch 12: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.7435 - accuracy: 0.9686 - val_loss: 1.1839 - val_accuracy: 0.8366
# Epoch 13/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7357 - accuracy: 0.9724
# Epoch 13: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.7357 - accuracy: 0.9724 - val_loss: 1.2054 - val_accuracy: 0.8288
# Epoch 14/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7194 - accuracy: 0.9772
# Epoch 14: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.7194 - accuracy: 0.9772 - val_loss: 1.1008 - val_accuracy: 0.8577
# Epoch 15/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7164 - accuracy: 0.9776
# Epoch 15: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.7164 - accuracy: 0.9776 - val_loss: 1.1220 - val_accuracy: 0.8512
# Epoch 16/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7163 - accuracy: 0.9777
# Epoch 16: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.7164 - accuracy: 0.9777 - val_loss: 1.0913 - val_accuracy: 0.8649
# Epoch 17/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7103 - accuracy: 0.9797
# Epoch 17: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.7103 - accuracy: 0.9797 - val_loss: 1.1503 - val_accuracy: 0.8436
# Epoch 18/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7053 - accuracy: 0.9814
# Epoch 18: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.7053 - accuracy: 0.9814 - val_loss: 1.0691 - val_accuracy: 0.8643
# Epoch 19/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7191 - accuracy: 0.9761
# Epoch 19: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.7190 - accuracy: 0.9761 - val_loss: 1.1943 - val_accuracy: 0.8398
# Epoch 20/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6979 - accuracy: 0.9836
# Epoch 20: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6982 - accuracy: 0.9836 - val_loss: 1.1200 - val_accuracy: 0.8581
# Epoch 21/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.7075 - accuracy: 0.9813
# Epoch 21: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.7075 - accuracy: 0.9813 - val_loss: 1.0908 - val_accuracy: 0.8635
# Epoch 22/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6951 - accuracy: 0.9851
# Epoch 22: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6951 - accuracy: 0.9851 - val_loss: 1.0592 - val_accuracy: 0.8681
# Epoch 23/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6968 - accuracy: 0.9848
# Epoch 23: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6968 - accuracy: 0.9848 - val_loss: 1.1470 - val_accuracy: 0.8535
# Epoch 24/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6998 - accuracy: 0.9840
# Epoch 24: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6998 - accuracy: 0.9840 - val_loss: 1.1165 - val_accuracy: 0.8589
# Epoch 25/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6894 - accuracy: 0.9872
# Epoch 25: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6896 - accuracy: 0.9872 - val_loss: 1.1541 - val_accuracy: 0.8526
# Epoch 26/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6970 - accuracy: 0.9857
# Epoch 26: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6970 - accuracy: 0.9857 - val_loss: 1.1169 - val_accuracy: 0.8571
# Epoch 27/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6868 - accuracy: 0.9887
# Epoch 27: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6868 - accuracy: 0.9887 - val_loss: 1.1169 - val_accuracy: 0.8569
# Epoch 28/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6874 - accuracy: 0.9882
# Epoch 28: val_accuracy did not improve from 0.87075
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6874 - accuracy: 0.9882 - val_loss: 1.0772 - val_accuracy: 0.8641
# Epoch 29/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6874 - accuracy: 0.9880
# Epoch 29: val_accuracy improved from 0.87075 to 0.87388, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 92s 65ms/step - loss: 0.6874 - accuracy: 0.9880 - val_loss: 1.0590 - val_accuracy: 0.8739
# Epoch 30/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6835 - accuracy: 0.9896
# Epoch 30: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6836 - accuracy: 0.9896 - val_loss: 1.1188 - val_accuracy: 0.8597
# Epoch 31/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6809 - accuracy: 0.9905
# Epoch 31: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6809 - accuracy: 0.9905 - val_loss: 1.2488 - val_accuracy: 0.8332
# Epoch 32/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6871 - accuracy: 0.9884
# Epoch 32: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 92s 65ms/step - loss: 0.6871 - accuracy: 0.9884 - val_loss: 1.1802 - val_accuracy: 0.8492
# Epoch 33/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6833 - accuracy: 0.9899
# Epoch 33: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6833 - accuracy: 0.9899 - val_loss: 1.1731 - val_accuracy: 0.8496
# Epoch 34/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6756 - accuracy: 0.9927
# Epoch 34: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6756 - accuracy: 0.9927 - val_loss: 1.1306 - val_accuracy: 0.8570
# Epoch 35/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6877 - accuracy: 0.9881
# Epoch 35: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6877 - accuracy: 0.9881 - val_loss: 1.1706 - val_accuracy: 0.8525
# Epoch 36/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6779 - accuracy: 0.9915
# Epoch 36: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6779 - accuracy: 0.9915 - val_loss: 1.1467 - val_accuracy: 0.8551
# Epoch 37/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6725 - accuracy: 0.9937
# Epoch 37: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6725 - accuracy: 0.9937 - val_loss: 1.1020 - val_accuracy: 0.8668
# Epoch 38/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6766 - accuracy: 0.9922
# Epoch 38: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6767 - accuracy: 0.9922 - val_loss: 1.1443 - val_accuracy: 0.8592
# Epoch 39/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6738 - accuracy: 0.9930
# Epoch 39: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6739 - accuracy: 0.9930 - val_loss: 1.1587 - val_accuracy: 0.8559
# Epoch 40/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6745 - accuracy: 0.9929
# Epoch 40: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6745 - accuracy: 0.9929 - val_loss: 1.2150 - val_accuracy: 0.8485
# Epoch 41/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6816 - accuracy: 0.9905
# Epoch 41: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6816 - accuracy: 0.9905 - val_loss: 1.1973 - val_accuracy: 0.8422
# Epoch 42/50
# 1407/1407 [==============================] - ETA: 0s - loss: 0.6706 - accuracy: 0.9943
# Epoch 42: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 92s 65ms/step - loss: 0.6706 - accuracy: 0.9943 - val_loss: 1.1886 - val_accuracy: 0.8418
# Epoch 43/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6706 - accuracy: 0.9942
# Epoch 43: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6706 - accuracy: 0.9942 - val_loss: 1.2493 - val_accuracy: 0.8377
# Epoch 44/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6749 - accuracy: 0.9929
# Epoch 44: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6750 - accuracy: 0.9929 - val_loss: 1.1921 - val_accuracy: 0.8478
# Epoch 45/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6815 - accuracy: 0.9901
# Epoch 45: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6816 - accuracy: 0.9900 - val_loss: 1.2155 - val_accuracy: 0.8440
# Epoch 46/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6778 - accuracy: 0.9921
# Epoch 46: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6778 - accuracy: 0.9921 - val_loss: 1.2079 - val_accuracy: 0.8450
# Epoch 47/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6742 - accuracy: 0.9932
# Epoch 47: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6742 - accuracy: 0.9932 - val_loss: 1.2232 - val_accuracy: 0.8438
# Epoch 48/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6749 - accuracy: 0.9926
# Epoch 48: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 64ms/step - loss: 0.6749 - accuracy: 0.9926 - val_loss: 1.2009 - val_accuracy: 0.8404
# Epoch 49/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6818 - accuracy: 0.9907
# Epoch 49: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6819 - accuracy: 0.9907 - val_loss: 1.1627 - val_accuracy: 0.8507
# Epoch 50/50
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.6757 - accuracy: 0.9928
# Epoch 50: val_accuracy did not improve from 0.87388
# 1407/1407 [==============================] - 91s 65ms/step - loss: 0.6757 - accuracy: 0.9928 - val_loss: 1.0949 - val_accuracy: 0.8711
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 1, 1, 2048)        23558528
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 200)               409800
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense_1 (Dense)             (None, 30)                6030
#
# =================================================================
# Total params: 23,974,358
# Trainable params: 23,928,918
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# # **4. 모델 저장**

# %%
save_path = '/content/'
team_name = 'team06'

# 트레이닝된 전체 모델을 저장합니다.
model.save(save_path +  'model_entire_'+ team_name + '.h5')

# %% [markdown]
# # **5. 모델 로드 및 평가**

# %%
save_path = '/content/'
team_name = 'team06'

model = keras.models.load_model(save_path + 'model_entire_' + team_name + '.h5')

model.evaluate(x_test_after, y_test)
# Out:
# 1250/1250 [==============================] - 15s 11ms/step - loss: 1.0949 - accuracy: 0.8711
# [1.0948773622512817, 0.8710500001907349]
